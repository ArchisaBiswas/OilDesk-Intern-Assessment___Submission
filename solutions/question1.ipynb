# %% [markdown]
# Question 1: Python Basics and Data Manipulation
#
# Objective: Demonstrate basic Python skills and data manipulation using Pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading a given CSV file containing metal prices into a Pandas DataFrame:

# %%
 df = pd.read_csv("../data/MarketData.csv")

# %%
df.head()
# Out:
#   Start Date             01/01/2010             Unnamed: 2  \
# 0   End Date             01/01/2023                    NaN
# 1        NaN                    NaN                    NaN
# 2        NaN  LME COPPER    3MO ($)  LME ALUMINUM  3MO ($)
# 3        NaN        LMCADS03 Comdty        LMAHDS03 Comdty
# 4        NaN       Settlement Price       Settlement Price
#
#               Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2  LME ZINC      3MO ($)  LME LEAD      3MO ($)  LME TIN       3MO ($)
# 3        LMZSDS03 Comdty        LMPBDS03 Comdty        LMSNDS03 Comdty
# 4       Settlement Price       Settlement Price       Settlement Price
#
#                 Unnamed: 6
# 0                      NaN
# 1                      NaN
# 2  Generic 1st 'CL' Future
# 3               CL1 Comdty
# 4         Settlement Price

# %%
df.tail()
# Out:
#       Start Date 01/01/2010 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3392  26/12/2022     8349.5     2389.5       2965     2273.5      23934
# 3393  27/12/2022     8349.5     2389.5       2965     2273.5      23934
# 3394  28/12/2022       8443       2381     3005.5       2218      24734
# 3395  29/12/2022       8418       2405     2984.5     2272.5      24915
# 3396  30/12/2022       8372       2378     2972.5       2293      24808
#
#      Unnamed: 6
# 3392      79.56
# 3393      79.53
# 3394      78.96
# 3395       78.4
# 3396      80.26

# %%
df.head(10)
# Out:
#    Start Date             01/01/2010             Unnamed: 2  \
# 0    End Date             01/01/2023                    NaN
# 1         NaN                    NaN                    NaN
# 2         NaN  LME COPPER    3MO ($)  LME ALUMINUM  3MO ($)
# 3         NaN        LMCADS03 Comdty        LMAHDS03 Comdty
# 4         NaN       Settlement Price       Settlement Price
# 5       Dates              PX_SETTLE              PX_SETTLE
# 6  01/01/2010                   7375                   2230
# 7  04/01/2010                   7500                   2267
# 8  05/01/2010                   7485                   2302
# 9  06/01/2010                   7660                   2377
#
#               Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2  LME ZINC      3MO ($)  LME LEAD      3MO ($)  LME TIN       3MO ($)
# 3        LMZSDS03 Comdty        LMPBDS03 Comdty        LMSNDS03 Comdty
# 4       Settlement Price       Settlement Price       Settlement Price
# 5              PX_SETTLE              PX_SETTLE              PX_SETTLE
# 6                   2560                   2432                  16950
# 7                   2574                   2515                  17450
# 8                   2575                 2522.5                  17375
# 9                   2718                   2680                  17825
#
#                 Unnamed: 6
# 0                      NaN
# 1                      NaN
# 2  Generic 1st 'CL' Future
# 3               CL1 Comdty
# 4         Settlement Price
# 5                PX_SETTLE
# 6                    79.36
# 7                    81.51
# 8                    81.77
# 9                    83.18

# %%
df.dtypes
# Out:
# Dates            str
# Copper       float64
# Aluminum     float64
# Zinc         float64
# Lead         float64
# Tin            int64
# CL_Future    float64
# dtype: object

# %%
df = pd.read_csv("../data/MarketData.csv", skiprows=6)

# %%
df.head()
# Out:
#         Dates  PX_SETTLE  PX_SETTLE.1  PX_SETTLE.2  PX_SETTLE.3  PX_SETTLE.4  \
# 0  01/01/2010     7375.0       2230.0       2560.0       2432.0        16950
# 1  04/01/2010     7500.0       2267.0       2574.0       2515.0        17450
# 2  05/01/2010     7485.0       2302.0       2575.0       2522.5        17375
# 3  06/01/2010     7660.0       2377.0       2718.0       2680.0        17825
# 4  07/01/2010     7535.0       2310.0       2607.0       2599.0        17475
#
#    PX_SETTLE.5
# 0        79.36
# 1        81.51
# 2        81.77
# 3        83.18
# 4        82.66

# %%
df.tail()
# Out:
#            Dates  PX_SETTLE  PX_SETTLE.1  PX_SETTLE.2  PX_SETTLE.3  \
# 3386  26/12/2022     8349.5       2389.5       2965.0       2273.5
# 3387  27/12/2022     8349.5       2389.5       2965.0       2273.5
# 3388  28/12/2022     8443.0       2381.0       3005.5       2218.0
# 3389  29/12/2022     8418.0       2405.0       2984.5       2272.5
# 3390  30/12/2022     8372.0       2378.0       2972.5       2293.0
#
#       PX_SETTLE.4  PX_SETTLE.5
# 3386        23934        79.56
# 3387        23934        79.53
# 3388        24734        78.96
# 3389        24915        78.40
# 3390        24808        80.26

# %%
df = df.rename(columns={
    "PX_SETTLE": "Copper",
    "PX_SETTLE.1": "Aluminum",
    "PX_SETTLE.2": "Zinc",
    "PX_SETTLE.3": "Lead",
    "PX_SETTLE.4": "Tin",
    "PX_SETTLE.5": "CL_Future"
})

# %%
df.head()
# Out:
#         Dates  Copper  Aluminum    Zinc    Lead    Tin  CL_Future
# 0  01/01/2010  7375.0    2230.0  2560.0  2432.0  16950      79.36
# 1  04/01/2010  7500.0    2267.0  2574.0  2515.0  17450      81.51
# 2  05/01/2010  7485.0    2302.0  2575.0  2522.5  17375      81.77
# 3  06/01/2010  7660.0    2377.0  2718.0  2680.0  17825      83.18
# 4  07/01/2010  7535.0    2310.0  2607.0  2599.0  17475      82.66

# %%
df.head(50)
# Out:
#         Dates  Copper  Aluminum    Zinc    Lead    Tin  CL_Future
# 0  2010-01-01  7375.0    2230.0  2560.0  2432.0  16950      79.36
# 1  2010-01-04  7500.0    2267.0  2574.0  2515.0  17450      81.51
# 2  2010-01-05  7485.0    2302.0  2575.0  2522.5  17375      81.77
# 3  2010-01-06  7660.0    2377.0  2718.0  2680.0  17825      83.18
# 4  2010-01-07  7535.0    2310.0  2607.0  2599.0  17475      82.66
# 5  2010-01-08  7461.0    2284.0  2521.0  2532.0  17340      82.75
# 6  2010-01-11  7567.5    2330.0  2573.0  2531.0  17900      82.52
# 7  2010-01-12  7455.0    2281.0  2475.0  2432.0  17900      80.79
# 8  2010-01-13  7485.0    2294.0  2489.0  2480.0  18000      79.65
# 9  2010-01-14  7490.0    2335.0  2503.0  2507.0  18425      79.39
# 10 2010-01-15  7430.0    2306.0  2470.0  2435.0  18100      78.00
# 11 2010-01-18  7500.0    2303.5  2481.0  2465.0  18000      78.00
# 12 2010-01-19  7545.0    2293.5  2503.0  2425.0  17975      79.02
# 13 2010-01-20  7375.0    2267.0  2444.0  2295.0  17775      77.62
# 14 2010-01-21  7275.0    2239.0  2400.0  2260.0  17750      76.08
# 15 2010-01-22  7390.0    2231.0  2350.0  2237.0  17775      74.54
# 16 2010-01-25  7465.0    2242.0  2315.0  2220.0  17900      75.26
# 17 2010-01-26  7381.0    2220.0  2318.5  2200.0  17975      74.71
# 18 2010-01-27  7230.0    2180.0  2236.0  2125.0  17850      73.67
# 19 2010-01-28  6898.0    2108.0  2158.0  2057.0  17550      73.64
# 20 2010-01-29  6745.0    2079.0  2110.0  2025.0  17200      72.89
# 21 2010-02-01  6790.0    2085.0  2145.0  2045.0  16150      74.43
# 22 2010-02-02  6815.0    2120.0  2161.0  2117.0  16450      77.23
# 23 2010-02-03  6590.0    2083.0  2092.0  2021.0  16600      76.98
# 24 2010-02-04  6390.0    2044.0  2021.0  1964.5  16175      73.14
# 25 2010-02-05  6280.0    1980.0  1940.0  1936.0  15450      71.19
# 26 2010-02-08  6450.0    2012.0  2022.5  1965.0  15200      71.89
# 27 2010-02-09  6590.0    2056.0  2104.0  2032.5  15455      73.75
# 28 2010-02-10  6535.0    2035.0  2114.0  2045.0  15700      74.52
# 29 2010-02-11  6939.0    2056.0  2180.0  2125.0  16200      75.28
# 30 2010-02-12  6810.0    2055.0  2170.0  2134.0  16225      74.13
# 31 2010-02-15  6865.0    2054.0  2200.0  2180.0  16495      74.13
# 32 2010-02-16  7144.0    2131.0  2337.0  2298.0  16700      77.01
# 33 2010-02-17  7130.0    2122.0  2300.0  2290.0  16750      77.33
# 34 2010-02-18  7265.0    2114.0  2310.0  2319.0  16950      79.06
# 35 2010-02-19  7431.5    2139.0  2365.0  2359.0  17000      79.81
# 36 2010-02-22  7330.0    2151.0  2292.5  2325.0  17175      80.16
# 37 2010-02-23  7132.0    2126.0  2220.0  2235.0  16825      78.86
# 38 2010-02-24  7152.5    2137.0  2204.0  2215.0  16975      80.00
# 39 2010-02-25  6999.0    2086.0  2116.0  2150.0  16725      78.17
# 40 2010-02-26  7195.0    2134.0  2195.0  2165.0  17125      79.66
# 41 2010-03-01  7400.0    2143.0  2220.0  2170.0  17050      78.70
# 42 2010-03-02  7491.0    2168.0  2255.0  2199.0  17090      79.68
# 43 2010-03-03  7580.0    2210.0  2320.0  2238.5  17350      80.87
# 44 2010-03-04  7398.0    2219.0  2259.0  2170.0  17255      80.21
# 45 2010-03-05  7545.0    2230.0  2349.0  2230.0  17405      81.50
# 46 2010-03-08  7470.0    2231.0  2370.0  2257.5  17300      81.87
# 47 2010-03-09  7510.0    2258.0  2375.0  2245.0  17550      81.49
# 48 2010-03-10  7440.0    2232.0  2376.0  2289.0  17750      82.09
# 49 2010-03-11  7464.0    2235.0  2340.0  2251.0  17350      82.11

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Filtering the data to include only 'Copper' and 'Zinc' for the year 2021:

# %%
filtered_data = df.filter(items=["Dates", "Copper", "Zinc"])

filtered_data["Dates"] = pd.to_datetime(filtered_data["Dates"], dayfirst=True)

filtered_data[(filtered_data["Dates"] >= "01/01/2021") & (filtered_data["Dates"] <= "31/12/2021")]
# Out:
#           Dates  Copper    Zinc
# 2870 2021-01-01  7766.0  2751.0
# 2871 2021-01-04  7860.5  2792.0
# 2872 2021-01-05  8002.0  2813.0
# 2873 2021-01-06  8037.5  2860.0
# 2874 2021-01-07  8179.0  2888.0
# ...         ...     ...     ...
# 3126 2021-12-27  9568.0  3519.0
# 3127 2021-12-28  9568.0  3519.0
# 3128 2021-12-29  9680.5  3513.0
# 3129 2021-12-30  9691.5  3532.5
# 3130 2021-12-31  9720.5  3534.0
#
# [261 rows x 3 columns]

# %% [markdown]
# Calculating the average price per month for each metal and plotting it:

# %%
metal_columns = ["Copper", "Aluminum", "Zinc", "Lead", "Tin"]

df_metals_average_per_month = df.copy()

for metal_column in metal_columns:
    df_metals_average_per_month[metal_column + "_avg_per_month"] = df_metals_average_per_month[metal_column].rolling(window=21).mean()

# %%
plt.figure(figsize=(12,6))

plt.plot(df["Dates"], df_metals_average_per_month["Copper_avg_per_month"], label="Copper")
plt.plot(df["Dates"], df_metals_average_per_month["Aluminum_avg_per_month"], label="Aluminum")
plt.plot(df["Dates"], df_metals_average_per_month["Zinc_avg_per_month"], label="Zinc")
plt.plot(df["Dates"], df_metals_average_per_month["Lead_avg_per_month"], label="Lead")
plt.plot(df["Dates"], df_metals_average_per_month["Tin_avg_per_month"], label="Tin")

plt.legend()
plt.title("21-Day Rolling Mean of Each Metal")
plt.xlabel("Date")
plt.ylabel("Price (Rolling Mean)")
plt.xticks(rotation=45)

plt.show()
